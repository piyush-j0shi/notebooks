# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15851, done.
# remote: Total 15851 (delta 0), reused 0 (delta 0), pack-reused 15851
# Receiving objects: 100% (15851/15851), 14.37 MiB | 11.05 MiB/s, done.
# Resolving deltas: 100% (10683/10683), done.

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	Dockerfile.cpu	       LICENSE	      scripts
# build		darknet_images.py	Dockerfile.gpu	       Makefile       src
# build.ps1	darknet.py		image_yolov3.sh        net_cam_v3.sh  vcpkg.json
# cfg		darknet_video.py	image_yolov4.sh        net_cam_v4.sh  vcpkg.json.opencv23
# cmake		data			include		       package.xml    video_yolov3.sh
# CMakeLists.txt	docker-compose.yml	json_mjpeg_streams.sh  README.md      video_yolov4.sh

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
# ...

# %%
# !pwd
# Out:
# /content/darknet

# %%
# %cd ..
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !ls /content/gdrive/MyDrive

# %%
# !ls /content/gdrive/MyDrive/yolov3

# %%
# !unzip /content/gdrive/MyDrive/yolov3/dataset_0.zip -d /content/darknet/data/

# %%
# !cp /content/darknet/cfg/yolov3.cfg /content/gdrive/MyDrive/yolov3/yolov3_custom.cfg

# %%
# !cp /content/gdrive/MyDrive/yolov3/yolov3_custom.cfg /content/darknet/cfg/

# %%
# !ls /content/darknet/cfg/yolov3_custom.cfg

# %%
# !cp /content/gdrive/MyDrive/yolov3/obj.data /content/darknet/data/
# !cp /content/gdrive/MyDrive/yolov3/obj.names /content/darknet/data/

# %%
# !wget http://pjreddie.com/media/files/darknet53.conv.74

# %%
# !cp /content/darknet53.conv.74 /content/darknet/

# %%
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show

# %%
# %cd darknet

# %%
# !cp /content/gdrive/MyDrive/yolov3/train.txt /content/darknet/data/dataset_0/
# !cp /content/gdrive/MyDrive/yolov3/valid.txt /content/darknet/data/dataset_0/

# %%
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show
