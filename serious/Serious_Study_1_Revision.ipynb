# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
fmnist = tf.keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = fmnist.load_data()

# %%
index = 43
plt.imshow(train_images[index])

# %%
train_images = train_images/ 255.0
test_images = test_images / 255.0

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation = tf.nn.relu),
    tf.keras.layers.Dense(10, activation = tf.nn.softmax)
])

model.compile(
    optimizer = tf.keras.optimizers.Adam(),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
model.fit(train_images, train_labels, epochs = 25)
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.4746 - accuracy: 0.8305
# Epoch 2/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3573 - accuracy: 0.8695
# Epoch 3/25
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3209 - accuracy: 0.8820
# Epoch 4/25
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.2982 - accuracy: 0.8908
# Epoch 5/25
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.2781 - accuracy: 0.8966
# Epoch 6/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2647 - accuracy: 0.9010
# Epoch 7/25
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.2518 - accuracy: 0.9056
# Epoch 8/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2402 - accuracy: 0.9104
# Epoch 9/25
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.2282 - accuracy: 0.9136
# Epoch 10/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2194 - accuracy: 0.9178
# Epoch 11/25
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.2124 - accuracy: 0.9216
# Epoch 12/25
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2027 - accuracy: 0.9224
# Epoch 13/25
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1966 - accuracy: 0.9258
# Epoch 14/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1902 - accuracy: 0.9286
# Epoch 15/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1821 - accuracy: 0.9305
# Epoch 16/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1775 - accuracy: 0.9333
# Epoch 17/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1710 - accuracy: 0.9355
# Epoch 18/25
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1655 - accuracy: 0.9374
# Epoch 19/25
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.1615 - accuracy: 0.9390
# Epoch 20/25
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.1567 - accuracy: 0.9416
# Epoch 21/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1519 - accuracy: 0.9435
# Epoch 22/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1473 - accuracy: 0.9437
# Epoch 23/25
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1477 - accuracy: 0.9444
# Epoch 24/25
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1387 - accuracy: 0.9479
# Epoch 25/25
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.1374 - accuracy: 0.9489

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3760 - accuracy: 0.8999
# [0.37598946690559387, 0.8999000191688538]

# %%
predictions = model.predict(test_images)
# Out:
# 313/313 [==============================] - 2s 6ms/step

# %%
index1 = 3

print(predictions[index1])
# Out:
# [3.6042284e-16 9.9999994e-01 4.7255637e-21 8.3610321e-13 9.8170797e-20
#  5.5772624e-27 2.1889182e-18 1.6096990e-38 1.1206322e-27 1.2769564e-31]

# %%
print(test_labels[index1])
# Out:
# 1
