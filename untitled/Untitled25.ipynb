# %%
import os
import torch
import torchvision

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/hymenoptera_data.zip -d /content/

# %%
class CustomDataset():
  def __init__(self, split, root_dir, transform):
    self.split = split
    self.root_dir = root_dir
    self.transform = transform

    self.image_path = []
    self.image_label = []

    self.class_map = {
        'ants' : 0,
        'bees' : 1
    }
