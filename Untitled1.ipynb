# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15851, done.
# remote: Total 15851 (delta 0), reused 0 (delta 0), pack-reused 15851
# Receiving objects: 100% (15851/15851), 14.37 MiB | 16.24 MiB/s, done.
# Resolving deltas: 100% (10683/10683), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
# ...

# %%
# %cd ..
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/yolov3/dataset.zip -d /content/darknet/data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/darknet/data/dataset/train_images/14745.txt
#   inflating: /content/darknet/data/dataset/train_images/14746.jpg
#   inflating: /content/darknet/data/dataset/train_images/14746.txt
#   inflating: /content/darknet/data/dataset/train_images/14747.jpg
#   inflating: /content/darknet/data/dataset/train_images/14747.txt
#   inflating: /content/darknet/data/dataset/train_images/14748.jpg
#   inflating: /content/darknet/data/dataset/train_images/14748.txt
#   inflating: /content/darknet/data/dataset/train_images/14749.jpg
#   inflating: /content/darknet/data/dataset/train_images/14749.txt
#   inflating: /content/darknet/data/dataset/train_images/14750.jpg
#   inflating: /content/darknet/data/dataset/train_images/14750.txt
#   inflating: /content/darknet/data/dataset/train_images/14751.jpg
#   inflating: /content/darknet/data/dataset/train_images/14751.txt
# ...

# %%
# !cp /content/gdrive/MyDrive/yolov3/yolov3_custom.cfg /content/darknet/cfg/

# %%
# !ls /content/darknet/cfg/yolov3_custom.cfg
# Out:
# /content/darknet/cfg/yolov3_custom.cfg

# %%
# !cp /content/gdrive/MyDrive/yolov3/generate_train.py /content/darknet/
# !cp /content/gdrive/MyDrive/yolov3/generate_train1.py /content/darknet/

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !python generate_train.py
# !python generate_train1.py

# %%
# !cp /content/gdrive/MyDrive/yolov3/obj.data /content/darknet/data/dataset
# !cp /content/gdrive/MyDrive/yolov3/obj.names /content/darknet/data/dataset

# %%
# %cd ..
# Out:
# /content

# %%
# !cp -r /content/gdrive/MyDrive/yolov3/backup /content/darknet/data/dataset/

# %%
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-07-10 16:28:24--  http://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://pjreddie.com/media/files/darknet53.conv.74 [following]
# --2024-07-10 16:28:24--  https://pjreddie.com/media/files/darknet53.conv.74
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  17.4MB/s    in 10s
#
# 2024-07-10 16:28:35 (15.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# %cd darknet

# %%
# !./darknet detector train data/dataset/obj.data cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.146032), count: 1, class_loss = 0.284159, iou_loss = 1.075429, total_loss = 1.359588
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.426370), count: 3, class_loss = 0.762961, iou_loss = 0.845366, total_loss = 1.608327
#  total_bbox = 30314, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.478771), count: 1, class_loss = 0.304652, iou_loss = 0.320513, total_loss = 0.625166
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001938, iou_loss = 0.000000, total_loss = 0.001938
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.545488), count: 3, class_loss = 0.785281, iou_loss = 0.610562, total_loss = 1.395842
# ...

# %%
# !cp -r /content/darknet/data/dataset/backup /content/gdrive/MyDrive/yolov3/backup

# %%
# !./darknet detector train data/dataset/obj.data cfg/yolov3_custom.cfg  /content/gdrive/MyDrive/yolov3/backup(1)/yolov3_custom_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.002100, iou_loss = 0.000000, total_loss = 0.002100
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.565675), count: 4, class_loss = 0.358516, iou_loss = 0.755712, total_loss = 1.114228
#  total_bbox = 7571, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000031, iou_loss = 0.000000, total_loss = 0.000031
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000087, iou_loss = 0.000000, total_loss = 0.000087
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.551160), count: 4, class_loss = 0.826898, iou_loss = 0.706921, total_loss = 1.533819
#  total_bbox = 7575, rewritten_bbox = 0.000000 %
# ...

# %%
import cv2

image = cv2.imread('/content/gdrive/MyDrive/yolov3/2531.jpg')
resized_image = cv2.resize(image, (image.shape[1] // 2, image.shape[0] // 2))  # Reduce size by half
cv2.imwrite('/content/gdrive/MyDrive/yolov3/2531_resized.jpg', resized_image)
# Out:
# True

# %%
# !./darknet detector test data/dataset/obj.data cfg/yolov3_custom.cfg /content/gdrive/MyDrive/yolov3/backup/yolov3_custom_last.weights /content/gdrive/MyDrive/yolov3/2531.jpg -thresh 0.3
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
imShow('predictions.jpg')
