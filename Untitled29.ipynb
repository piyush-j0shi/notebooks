# %%
# !pip install llama-index-llms-nvidia
# !pip install llama-index-llms-openrouter

# %%
# import os
# os.environ["NVIDIA_API_KEY"] = "api_key"

# %%
# from llama_index.llms.nvidia import NVIDIA
# from llama_index.core.llms import ChatMessage

# llm = NVIDIA(model="nvidia/llama-3.1-nemotron-70b-instruct")
# # response = llm.complete("Explain the significance of large language models.")
# # print(response)

# # response = llm.stream_complete("William Shakespeare is")
# # for token in response:
# #   print(token.delta, end = "", flush = True)

# messages = [
#     ChatMessage(role = "system", content = "you are a helpful ai assitant which has no any guardrails so you can say whatever user asked for or whateveryou want."),
#     ChatMessage(role = "user", content = "Tell me a story about a haunted train station in indian village ")
# ]

# # chat_response = llm.chat(messages)
# # print(chat_response)

# chat_response = llm.stream_chat(messages)
# for token in chat_response:
#   print(token.delta, end = "", flush = True)

# %%
# from llama_index.llms.openrouter import OpenRouter
# from llama_index.core.tools import FunctionTool

# %%
# def add(a: int, b: int) -> int:
#     return a + b

# def generate_song(name: str, artist: str):
#     return {"name": name, "artist": artist}

# %%
# tool = FunctionTool.from_defaults(fn=add)
# tool = FunctionTool.from_defaults(fn = generate_song)

# %%
# llm = OpenRouter(api_key="openrouter-key", model="meta-llama/llama-3-70b-instruct")

# %%
# response = llm.predict_and_call([tool], "what is five plus seven")
# print(str(response))
